# %% [markdown]
# # IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import time
import matplotlib.pyplot as plt
import zipfile
import cv2
from skimage import io
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler, normalize
import os
import random
from glob import glob
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications import DenseNet121, DenseNet169
from skimage.metrics import structural_similarity as ssim
from sklearn.model_selection import train_test_split
# %matplotlib inline
# create a image generator
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
# Use plotly to plot interactive bar chart
import plotly.graph_objects as go
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# data containing path to Brain MRI and their corresponding mask
brain_df = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')

# %%
  brain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
brain_df.head(10)
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
# 5  TCGA_CS_5395            2.0                 4.0             2        2.0
# 6  TCGA_CS_5396            3.0                 3.0             2        3.0
# 7  TCGA_CS_5397            NaN                 4.0             1        2.0
# 8  TCGA_CS_6186            2.0                 4.0             1        2.0
# 9  TCGA_CS_6188            2.0                 4.0             3        2.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
# 5          NaN              3.0           2                3.0
# 6          2.0              2.0           3                3.0
# 7          3.0              3.0           2                1.0
# 8          1.0              3.0           2                2.0
# 9          3.0              3.0           2                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
# 5                        1.0                1.0         3.0             5.0
# 6                        2.0                1.0         3.0             2.0
# 7                        2.0                1.0         1.0             6.0
# 8                        2.0                1.0         3.0             2.0
# 9                        2.0                1.0         3.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0
# 5     2.0                       43.0   2.0        NaN      1.0
# 6     1.0                       53.0   3.0        2.0      0.0
# 7     1.0                       54.0   3.0        2.0      1.0
# 8     2.0                       58.0   3.0        2.0      1.0
# 9     2.0                       48.0   3.0        2.0      0.0

# %%
data_map = []
for sub_dir_path in glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    #if os.path.isdir(sub_path_dir):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            image_path = sub_dir_path + '/' + filename
            data_map.extend([dir_name, image_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
df = pd.DataFrame({"patient_id" : data_map[::2],
                   "path" : data_map[1::2]})
df.head()
# Out:
#               patient_id                                               path
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
df_imgs = df[~df['path'].str.contains("mask")]
df_masks = df[df['path'].str.contains("mask")]

# File path line length images for later sorting
BASE_LEN = 89 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_ <-!!!43.tif)
END_IMG_LEN = 4 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->.tif)
END_MASK_LEN = 9 # (/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->_mask.tif)

# Data sorting
imgs = sorted(df_imgs["path"].values, key=lambda x : int(x[BASE_LEN:-END_IMG_LEN]))
masks = sorted(df_masks["path"].values, key=lambda x : int(x[BASE_LEN:-END_MASK_LEN]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Path to the Image:", imgs[idx], "\nPath to the Mask:", masks[idx])
# Out:
# Path to the Image: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7608_19940304/TCGA_HT_7608_19940304_7.tif
# Path to the Mask: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_7608_19940304/TCGA_HT_7608_19940304_7_mask.tif

# %%
# Final dataframe
brain_df = pd.DataFrame({"patient_id": df_imgs.patient_id.values,
                         "image_path": imgs,
                         "mask_path": masks
                        })
def pos_neg_diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    if value > 0 : 
        return 1
    else:
        return 0
    
brain_df['mask'] = brain_df['mask_path'].apply(lambda x: pos_neg_diagnosis(x))
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
'''pd.set_option('display.max_columns', 20)
pd.set_option('display.max_colwidth', 50)'''
brain_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                                                            image_path  \
# 0      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_1.tif
# 1      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_8162_19961029/TCGA_DU_8162_19961029_1.tif
# 2      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_A4MT_20020212/TCGA_FG_A4MT_20020212_1.tif
# 3      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_5964_20010511/TCGA_FG_5964_20010511_1.tif
# 4      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TS_19970726/TCGA_DU_A5TS_19970726_1.tif
# ...                                                                                               ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_86.tif
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61A_20000127/TCGA_HT_A61A_20000127_87.tif
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_87.tif
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61A_20000127/TCGA_HT_A61A_20000127_88.tif
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_88.tif
#
#                                                                                                  mask_path  \
# 0      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_1_mask.tif
# 1      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_8162_19961029/TCGA_DU_8162_19961029_1_mask.tif
# 2      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_A4MT_20020212/TCGA_FG_A4MT_20020212_1_mask.tif
# 3      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_5964_20010511/TCGA_FG_5964_20010511_1_mask.tif
# 4      /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TS_19970726/TCGA_DU_A5TS_19970726_1_mask.tif
# ...                                                                                                    ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_86_mask.tif
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61A_20000127/TCGA_HT_A61A_20000127_87_mask.tif
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_87_mask.tif
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61A_20000127/TCGA_HT_A61A_20000127_88_mask.tif
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_HT_A61B_19991127/TCGA_HT_A61B_19991127_88_mask.tif
#
#       mask
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 3924     0
# 3925     0
# 3926     0
# 3927     0
# 3928     0
#
# [3929 rows x 4 columns]

# %% [markdown]
# # Phân loại

# %%
# Drop the patient id column
brain_df_train = brain_df.drop(columns = ['patient_id'])
brain_df_train.shape
# Out:
# (3929, 3)

# %%
# Convert the data in mask column to string format, to use categorical mode in flow_from_dataframe
# You will get this error message if you comment out the following code line:
# TypeError: If class_mode="categorical", y_col="mask" column values must be type string, list or tuple.
brain_df_train['mask'] = brain_df_train['mask'].apply(lambda x: str(x))

# %%
brain_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  3929 non-null   object
#  1   mask_path   3929 non-null   object
#  2   mask        3929 non-null   object
# dtypes: object(3)
# memory usage: 92.2+ KB

# %%
batch_size = 16
epochs = 100
image_size = 256

# %%
# split the data into train and test data
train, test = train_test_split(brain_df_train, test_size = 0.2)
# create a image generator
# Create a data generator which scales the data from 0 to 1 and makes validation split of 0.15
train_datagen  = ImageDataGenerator(
    rescale=1./255.,
    validation_split=0.3,
    rotation_range=20,            # Rotate images by 20 degrees
    width_shift_range=0.1,        # Randomly shift images horizontally by 10% of the width
    height_shift_range=0.1,       # Randomly shift images vertically by 10% of the height
    zoom_range=0.2,               # Apply random zooming in the range of 0.8 to 1.2
    horizontal_flip=True         # Flip images horizontally
)

# %%
# Đường dẫn tới hình ảnh
image_path = '../input/lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_11.tif'

# Đọc hình ảnh ban đầu
image = plt.imread(image_path)

# Số lượng phiên bản mới muốn tạo ra
num_augmented_images = 5

# Tạo ra các phiên bản biến đổi của hình ảnh
augmented_images = []
for _ in range(num_augmented_images):
    augmented_image = train_datagen.random_transform(image)
    augmented_images.append(augmented_image)

# Hiển thị hình ảnh ban đầu và các phiên bản mới
plt.figure(figsize=(12, 6))

# Hình ảnh ban đầu
plt.subplot(2, 3, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

# Các phiên bản mới
for i in range(num_augmented_images):
    plt.subplot(2, 3, i + 2)
    plt.imshow(augmented_images[i])
    plt.title(f'Augmented Image {i + 1}')
    plt.axis('off')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
train_generator=train_datagen.flow_from_dataframe(
dataframe=train,
directory= './',
x_col='image_path',
y_col='mask',
subset="training",
batch_size=batch_size,
shuffle=True,
class_mode="categorical",
target_size=(256,256))


valid_generator=train_datagen.flow_from_dataframe(
dataframe=train,
directory= './',
x_col='image_path',
y_col='mask',
subset="validation",
batch_size=batch_size,
shuffle=True,
class_mode="categorical",
target_size=(256,256))

# Create a data generator for test images
test_datagen=ImageDataGenerator(rescale=1./255.)

test_generator=test_datagen.flow_from_dataframe(
dataframe=test,
directory= './',
x_col='image_path',
y_col='mask',
batch_size=batch_size,
shuffle=False,
class_mode='categorical',
target_size=(256,256))
# Out:
# Found 2201 validated image filenames belonging to 2 classes.
# Found 942 validated image filenames belonging to 2 classes.
# Found 786 validated image filenames belonging to 2 classes.

# %%
# Calculate the number of batches in each generator
train_steps = train_generator.n
valid_steps = valid_generator.n
test_steps = test_generator.n

# Create a list of labels for the x-axis
labels = ['Train', 'Validation', 'Test']

# Create a list of values for the y-axis
values = [train_steps, valid_steps, test_steps]

# Define the colors for each bar
colors = ['blue', 'orange', 'green']

# Plot the bar chart
plt.bar(labels, values, color=colors)
plt.xlabel('Generator')
plt.ylabel('Number of Batches')
plt.title('Generator Statistics')

# Add the numbers on top of the bars
for i, value in enumerate(values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # DenseNet121

# %%
num_classes = 2
adam = tf.keras.optimizers.Adam(lr=0.001)
# create the base pre-trained model
base_model = tf.keras.applications.DenseNet121(weights='imagenet', include_top=False,input_shape=(256,256,3))
for layer in base_model.layers:
    layer.trainable = False
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
# multi output
predictions = Dense(2,activation = 'softmax')(x)
# this is the model we will train
model_DenseNet121 = Model(inputs=base_model.input, outputs=predictions)
#display(tf.keras.utils.plot_model(model_DenseNet121, to_file='model_DenseNet121.png', show_shapes=True))
# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers


# compile the model (should be done *after* setting layers to non-trainable)
model_DenseNet121.compile(optimizer=adam, loss='categorical_crossentropy',metrics=['accuracy'])


checkpoint_filepath_transfer_DenseNet121 = 'model_DenseNet121.hdf5'
mc = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath_transfer_DenseNet121, monitor='val_loss',mode='auto',save_best_only=True)
# Early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience =30)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
model_DenseNet121.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 128, 128, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 128, 128, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 130, 130, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 64, 64, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 64, 64, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 64, 64, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 64, 64, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 64, 64, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 64, 64, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 64, 64, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 64, 64, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 64, 64, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 64, 64, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 64, 64, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 64, 64, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 32, 32, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 32, 32, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 32, 32, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 32, 32, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 32, 32, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 32, 32, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 32, 32, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 32, 32, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 32, 32, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 32, 32, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 32, 32, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 32, 32, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 32, 32, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 32, 32, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 32, 32, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 32, 32, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 32, 32, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 32, 32, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 32, 32, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 32, 32, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 32, 32, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 32, 32, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 32, 32, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 32, 32, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 32, 32, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 16, 16, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 16, 16, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 16, 16, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 16, 16, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 16, 16, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 16, 16, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 16, 16, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 16, 16, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block6_1_conv[0][0]']
# ...
#
#  conv5_block9_concat (Concatena  (None, 8, 8, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 8, 8, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 8, 8, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 8, 8, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 8, 8, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 8, 8, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 8, 8, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 8, 8, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 8, 8, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 8, 8, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 8, 8, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 8, 8, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 8, 8, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 8, 8, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 8, 8, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 8, 8, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 8, 8, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 8, 8, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 8, 8, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 8, 8, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 8, 8, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 8, 8, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 8, 8, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 8, 8, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 8, 8, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 8, 8, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 8, 8, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 8, 8, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 8, 8, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 8, 8, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 8, 8, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['relu[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization (BatchNorm  (None, 1024)        4096        ['global_average_pooling2d[0][0]'
#  alization)                                                      ]
#
#  dropout (Dropout)              (None, 1024)         0           ['batch_normalization[0][0]']
#
#  dense (Dense)                  (None, 256)          262400      ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256)         1024        ['dense[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['batch_normalization_1[0][0]']
#
#  dense_1 (Dense)                (None, 2)            514         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7,305,538
# Trainable params: 265,474
# Non-trainable params: 7,040,064
# __________________________________________________________________________________________________

# %%
start_time = time.time()
history_DenseNet121 = model_DenseNet121.fit(train_generator,
                    steps_per_epoch=len(train_generator),
                    epochs=epochs,
                    validation_data=valid_generator,
                    validation_steps=len(valid_generator),
                    callbacks=[mc, es, reduce_lr])
end_time = time.time()
DenseNet121_time = end_time-start_time
# Out:
# Epoch 1/100
# 138/138 [==============================] - 81s 483ms/step - loss: 0.6264 - accuracy: 0.7592 - val_loss: 0.3564 - val_accuracy: 0.8355 - lr: 0.0010
# Epoch 2/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.4235 - accuracy: 0.8142 - val_loss: 0.3478 - val_accuracy: 0.8301 - lr: 0.0010
# Epoch 3/100
# 138/138 [==============================] - 56s 408ms/step - loss: 0.3834 - accuracy: 0.8192 - val_loss: 0.2965 - val_accuracy: 0.8715 - lr: 0.0010
# Epoch 4/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.3385 - accuracy: 0.8437 - val_loss: 0.2716 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 5/100
# 138/138 [==============================] - 51s 371ms/step - loss: 0.3138 - accuracy: 0.8619 - val_loss: 0.2822 - val_accuracy: 0.8694 - lr: 0.0010
# Epoch 6/100
# 138/138 [==============================] - 57s 410ms/step - loss: 0.3079 - accuracy: 0.8610 - val_loss: 0.2769 - val_accuracy: 0.8747 - lr: 0.0010
# Epoch 7/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.3059 - accuracy: 0.8619 - val_loss: 0.2975 - val_accuracy: 0.8652 - lr: 0.0010
# Epoch 8/100
# 138/138 [==============================] - 51s 371ms/step - loss: 0.2758 - accuracy: 0.8778 - val_loss: 0.3053 - val_accuracy: 0.8631 - lr: 0.0010
# Epoch 9/100
# 138/138 [==============================] - 51s 369ms/step - loss: 0.2748 - accuracy: 0.8760 - val_loss: 0.2507 - val_accuracy: 0.9002 - lr: 0.0010
# Epoch 10/100
# 138/138 [==============================] - 51s 371ms/step - loss: 0.2683 - accuracy: 0.8878 - val_loss: 0.2480 - val_accuracy: 0.8907 - lr: 0.0010
# Epoch 11/100
# 138/138 [==============================] - 50s 361ms/step - loss: 0.2803 - accuracy: 0.8832 - val_loss: 0.2738 - val_accuracy: 0.8917 - lr: 0.0010
# Epoch 12/100
# 138/138 [==============================] - 54s 386ms/step - loss: 0.2595 - accuracy: 0.8873 - val_loss: 0.2422 - val_accuracy: 0.9119 - lr: 0.0010
# Epoch 13/100
# 138/138 [==============================] - 57s 412ms/step - loss: 0.2434 - accuracy: 0.8941 - val_loss: 0.2559 - val_accuracy: 0.8992 - lr: 0.0010
# Epoch 14/100
# 138/138 [==============================] - 51s 365ms/step - loss: 0.2324 - accuracy: 0.9005 - val_loss: 0.2607 - val_accuracy: 0.8907 - lr: 0.0010
# Epoch 15/100
# 138/138 [==============================] - 52s 375ms/step - loss: 0.2343 - accuracy: 0.8991 - val_loss: 0.2403 - val_accuracy: 0.9045 - lr: 0.0010
# Epoch 16/100
# 138/138 [==============================] - 50s 364ms/step - loss: 0.2452 - accuracy: 0.9014 - val_loss: 0.2421 - val_accuracy: 0.8992 - lr: 0.0010
# Epoch 17/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.2352 - accuracy: 0.8987 - val_loss: 0.2189 - val_accuracy: 0.9140 - lr: 0.0010
# Epoch 18/100
# 138/138 [==============================] - 51s 373ms/step - loss: 0.2315 - accuracy: 0.8950 - val_loss: 0.2574 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 19/100
# 138/138 [==============================] - 51s 372ms/step - loss: 0.2494 - accuracy: 0.8919 - val_loss: 0.2355 - val_accuracy: 0.8981 - lr: 0.0010
# Epoch 20/100
# 138/138 [==============================] - 54s 390ms/step - loss: 0.2302 - accuracy: 0.9014 - val_loss: 0.2272 - val_accuracy: 0.9045 - lr: 0.0010
# Epoch 21/100
# 138/138 [==============================] - 57s 415ms/step - loss: 0.2202 - accuracy: 0.9096 - val_loss: 0.2311 - val_accuracy: 0.9045 - lr: 0.0010
# Epoch 22/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.2201 - accuracy: 0.9087 - val_loss: 0.2448 - val_accuracy: 0.8960 - lr: 0.0010
# Epoch 23/100
# 138/138 [==============================] - 53s 382ms/step - loss: 0.2101 - accuracy: 0.9105 - val_loss: 0.2318 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 24/100
# 138/138 [==============================] - 53s 382ms/step - loss: 0.2082 - accuracy: 0.9096 - val_loss: 0.2316 - val_accuracy: 0.9098 - lr: 1.0000e-04
# Epoch 25/100
# 138/138 [==============================] - 53s 379ms/step - loss: 0.1982 - accuracy: 0.9141 - val_loss: 0.2347 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 26/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1933 - accuracy: 0.9250 - val_loss: 0.2276 - val_accuracy: 0.9098 - lr: 1.0000e-04
# Epoch 27/100
# 138/138 [==============================] - 51s 371ms/step - loss: 0.1874 - accuracy: 0.9150 - val_loss: 0.2391 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 28/100
# 138/138 [==============================] - 53s 385ms/step - loss: 0.1856 - accuracy: 0.9223 - val_loss: 0.2236 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 29/100
# 138/138 [==============================] - 51s 368ms/step - loss: 0.1850 - accuracy: 0.9232 - val_loss: 0.2287 - val_accuracy: 0.9140 - lr: 1.0000e-04
# Epoch 30/100
# 138/138 [==============================] - 51s 369ms/step - loss: 0.1808 - accuracy: 0.9246 - val_loss: 0.2149 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 31/100
# 138/138 [==============================] - 51s 373ms/step - loss: 0.1791 - accuracy: 0.9300 - val_loss: 0.2082 - val_accuracy: 0.9172 - lr: 1.0000e-04
# Epoch 32/100
# 138/138 [==============================] - 50s 364ms/step - loss: 0.1670 - accuracy: 0.9341 - val_loss: 0.2192 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 33/100
# 138/138 [==============================] - 50s 364ms/step - loss: 0.1589 - accuracy: 0.9359 - val_loss: 0.2255 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 34/100
# 138/138 [==============================] - 50s 363ms/step - loss: 0.1729 - accuracy: 0.9259 - val_loss: 0.2122 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 35/100
# 138/138 [==============================] - 51s 371ms/step - loss: 0.1681 - accuracy: 0.9337 - val_loss: 0.2295 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 36/100
# 138/138 [==============================] - 52s 373ms/step - loss: 0.1666 - accuracy: 0.9323 - val_loss: 0.2139 - val_accuracy: 0.9204 - lr: 1.0000e-04
# Epoch 37/100
# 138/138 [==============================] - 50s 365ms/step - loss: 0.1692 - accuracy: 0.9269 - val_loss: 0.2208 - val_accuracy: 0.9204 - lr: 1.0000e-04
# Epoch 38/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.1662 - accuracy: 0.9296 - val_loss: 0.2272 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 39/100
# 138/138 [==============================] - 51s 367ms/step - loss: 0.1609 - accuracy: 0.9259 - val_loss: 0.2106 - val_accuracy: 0.9204 - lr: 1.0000e-04
# Epoch 40/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1873 - accuracy: 0.9214 - val_loss: 0.2189 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 41/100
# 138/138 [==============================] - 52s 376ms/step - loss: 0.1644 - accuracy: 0.9382 - val_loss: 0.2249 - val_accuracy: 0.9119 - lr: 1.0000e-04
# Epoch 42/100
# 138/138 [==============================] - 51s 369ms/step - loss: 0.1734 - accuracy: 0.9237 - val_loss: 0.2256 - val_accuracy: 0.9087 - lr: 1.0000e-04
# Epoch 43/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1669 - accuracy: 0.9341 - val_loss: 0.2086 - val_accuracy: 0.9268 - lr: 1.0000e-04
# Epoch 44/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.1566 - accuracy: 0.9341 - val_loss: 0.2287 - val_accuracy: 0.9055 - lr: 1.0000e-04
# Epoch 45/100
# 138/138 [==============================] - 52s 374ms/step - loss: 0.1523 - accuracy: 0.9350 - val_loss: 0.2147 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 46/100
# 138/138 [==============================] - 52s 376ms/step - loss: 0.1691 - accuracy: 0.9332 - val_loss: 0.2315 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 47/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1750 - accuracy: 0.9346 - val_loss: 0.2213 - val_accuracy: 0.9055 - lr: 1.0000e-04
# Epoch 48/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1435 - accuracy: 0.9423 - val_loss: 0.2159 - val_accuracy: 0.9193 - lr: 1.0000e-04
# Epoch 49/100
# 138/138 [==============================] - 52s 380ms/step - loss: 0.1728 - accuracy: 0.9323 - val_loss: 0.2064 - val_accuracy: 0.9193 - lr: 1.0000e-04
# Epoch 50/100
# 138/138 [==============================] - 53s 384ms/step - loss: 0.1526 - accuracy: 0.9400 - val_loss: 0.2206 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 51/100
# 138/138 [==============================] - 54s 388ms/step - loss: 0.1527 - accuracy: 0.9418 - val_loss: 0.2205 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 52/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.1537 - accuracy: 0.9341 - val_loss: 0.2245 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 53/100
# 138/138 [==============================] - 53s 386ms/step - loss: 0.1619 - accuracy: 0.9318 - val_loss: 0.2186 - val_accuracy: 0.9045 - lr: 1.0000e-04
# Epoch 54/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.1462 - accuracy: 0.9396 - val_loss: 0.2194 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 55/100
# 138/138 [==============================] - 54s 387ms/step - loss: 0.1492 - accuracy: 0.9387 - val_loss: 0.2210 - val_accuracy: 0.9214 - lr: 1.0000e-04
# Epoch 56/100
# 138/138 [==============================] - 53s 386ms/step - loss: 0.1581 - accuracy: 0.9382 - val_loss: 0.2224 - val_accuracy: 0.9161 - lr: 1.0000e-04
# Epoch 57/100
# 138/138 [==============================] - 53s 381ms/step - loss: 0.1682 - accuracy: 0.9346 - val_loss: 0.2318 - val_accuracy: 0.9098 - lr: 1.0000e-04
# Epoch 58/100
# 138/138 [==============================] - 54s 387ms/step - loss: 0.1527 - accuracy: 0.9400 - val_loss: 0.2270 - val_accuracy: 0.9098 - lr: 1.0000e-04
# Epoch 59/100
# 138/138 [==============================] - 53s 386ms/step - loss: 0.1497 - accuracy: 0.9428 - val_loss: 0.2241 - val_accuracy: 0.9161 - lr: 1.0000e-04
# Epoch 60/100
# 138/138 [==============================] - 54s 390ms/step - loss: 0.1484 - accuracy: 0.9391 - val_loss: 0.2136 - val_accuracy: 0.9225 - lr: 1.0000e-04
# Epoch 61/100
# 138/138 [==============================] - 53s 386ms/step - loss: 0.1503 - accuracy: 0.9464 - val_loss: 0.2375 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 62/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1470 - accuracy: 0.9400 - val_loss: 0.2139 - val_accuracy: 0.9183 - lr: 1.0000e-04
# Epoch 63/100
# 138/138 [==============================] - 53s 384ms/step - loss: 0.1629 - accuracy: 0.9391 - val_loss: 0.2214 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 64/100
# 138/138 [==============================] - 53s 381ms/step - loss: 0.1601 - accuracy: 0.9359 - val_loss: 0.2168 - val_accuracy: 0.9214 - lr: 1.0000e-04
# Epoch 65/100
# 138/138 [==============================] - 53s 387ms/step - loss: 0.1376 - accuracy: 0.9491 - val_loss: 0.1989 - val_accuracy: 0.9246 - lr: 1.0000e-04
# Epoch 66/100
# 138/138 [==============================] - 52s 375ms/step - loss: 0.1677 - accuracy: 0.9364 - val_loss: 0.2154 - val_accuracy: 0.9161 - lr: 1.0000e-04
# Epoch 67/100
# 138/138 [==============================] - 52s 375ms/step - loss: 0.1354 - accuracy: 0.9446 - val_loss: 0.2435 - val_accuracy: 0.9045 - lr: 1.0000e-04
# Epoch 68/100
# 138/138 [==============================] - 52s 378ms/step - loss: 0.1533 - accuracy: 0.9378 - val_loss: 0.2179 - val_accuracy: 0.9045 - lr: 1.0000e-04
# Epoch 69/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.1601 - accuracy: 0.9418 - val_loss: 0.2256 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 70/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.1424 - accuracy: 0.9441 - val_loss: 0.2225 - val_accuracy: 0.9140 - lr: 1.0000e-04
# Epoch 71/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.1425 - accuracy: 0.9418 - val_loss: 0.2169 - val_accuracy: 0.9172 - lr: 1.0000e-04
# Epoch 72/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1549 - accuracy: 0.9400 - val_loss: 0.2220 - val_accuracy: 0.9161 - lr: 1.0000e-04
# Epoch 73/100
# 138/138 [==============================] - 51s 374ms/step - loss: 0.1274 - accuracy: 0.9527 - val_loss: 0.2218 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 74/100
# 138/138 [==============================] - 52s 374ms/step - loss: 0.1384 - accuracy: 0.9437 - val_loss: 0.2310 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 75/100
# 138/138 [==============================] - 52s 378ms/step - loss: 0.1314 - accuracy: 0.9437 - val_loss: 0.2180 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 76/100
# 138/138 [==============================] - 52s 380ms/step - loss: 0.1507 - accuracy: 0.9455 - val_loss: 0.2234 - val_accuracy: 0.9214 - lr: 1.0000e-04
# Epoch 77/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.1365 - accuracy: 0.9523 - val_loss: 0.2238 - val_accuracy: 0.9183 - lr: 1.0000e-04
# Epoch 78/100
# 138/138 [==============================] - 52s 378ms/step - loss: 0.1160 - accuracy: 0.9577 - val_loss: 0.2354 - val_accuracy: 0.9087 - lr: 1.0000e-04
# Epoch 79/100
# 138/138 [==============================] - 52s 377ms/step - loss: 0.1312 - accuracy: 0.9473 - val_loss: 0.1979 - val_accuracy: 0.9257 - lr: 1.0000e-04
# Epoch 80/100
# 138/138 [==============================] - 54s 388ms/step - loss: 0.1465 - accuracy: 0.9400 - val_loss: 0.2184 - val_accuracy: 0.9172 - lr: 1.0000e-04
# Epoch 81/100
# 138/138 [==============================] - 53s 386ms/step - loss: 0.1177 - accuracy: 0.9568 - val_loss: 0.2061 - val_accuracy: 0.9204 - lr: 1.0000e-04
# Epoch 82/100
# 138/138 [==============================] - 53s 381ms/step - loss: 0.1542 - accuracy: 0.9382 - val_loss: 0.2263 - val_accuracy: 0.9204 - lr: 1.0000e-04
# Epoch 83/100
# 138/138 [==============================] - 53s 385ms/step - loss: 0.1345 - accuracy: 0.9441 - val_loss: 0.2200 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 84/100
# 138/138 [==============================] - 51s 373ms/step - loss: 0.1366 - accuracy: 0.9473 - val_loss: 0.2292 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 85/100
# 138/138 [==============================] - 53s 381ms/step - loss: 0.1341 - accuracy: 0.9459 - val_loss: 0.2036 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 86/100
# 138/138 [==============================] - 53s 384ms/step - loss: 0.1304 - accuracy: 0.9473 - val_loss: 0.2217 - val_accuracy: 0.9140 - lr: 1.0000e-04
# Epoch 87/100
# 138/138 [==============================] - 52s 375ms/step - loss: 0.1357 - accuracy: 0.9464 - val_loss: 0.2030 - val_accuracy: 0.9289 - lr: 1.0000e-04
# Epoch 88/100
# 138/138 [==============================] - 53s 382ms/step - loss: 0.1420 - accuracy: 0.9428 - val_loss: 0.2276 - val_accuracy: 0.9172 - lr: 1.0000e-04
# Epoch 89/100
# 138/138 [==============================] - 58s 418ms/step - loss: 0.1430 - accuracy: 0.9487 - val_loss: 0.2279 - val_accuracy: 0.9045 - lr: 1.0000e-04
# Epoch 90/100
# 138/138 [==============================] - 53s 384ms/step - loss: 0.1413 - accuracy: 0.9487 - val_loss: 0.2205 - val_accuracy: 0.9140 - lr: 1.0000e-04
# Epoch 91/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.1559 - accuracy: 0.9423 - val_loss: 0.2168 - val_accuracy: 0.9161 - lr: 1.0000e-04
# Epoch 92/100
# 138/138 [==============================] - 51s 372ms/step - loss: 0.1230 - accuracy: 0.9573 - val_loss: 0.2114 - val_accuracy: 0.9246 - lr: 1.0000e-04
# Epoch 93/100
# 138/138 [==============================] - 52s 376ms/step - loss: 0.1342 - accuracy: 0.9505 - val_loss: 0.2291 - val_accuracy: 0.9246 - lr: 1.0000e-04
# Epoch 94/100
# 138/138 [==============================] - 53s 385ms/step - loss: 0.1412 - accuracy: 0.9478 - val_loss: 0.2259 - val_accuracy: 0.9193 - lr: 1.0000e-04
# Epoch 95/100
# 138/138 [==============================] - 51s 367ms/step - loss: 0.1282 - accuracy: 0.9468 - val_loss: 0.2313 - val_accuracy: 0.9066 - lr: 1.0000e-04
# Epoch 96/100
# 138/138 [==============================] - 52s 379ms/step - loss: 0.1293 - accuracy: 0.9496 - val_loss: 0.2186 - val_accuracy: 0.9193 - lr: 1.0000e-04
# Epoch 97/100
# 138/138 [==============================] - 52s 375ms/step - loss: 0.1298 - accuracy: 0.9478 - val_loss: 0.2281 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 98/100
# 138/138 [==============================] - 51s 370ms/step - loss: 0.1275 - accuracy: 0.9491 - val_loss: 0.2112 - val_accuracy: 0.9130 - lr: 1.0000e-04
# Epoch 99/100
# 138/138 [==============================] - 52s 375ms/step - loss: 0.1351 - accuracy: 0.9514 - val_loss: 0.2171 - val_accuracy: 0.9193 - lr: 1.0000e-04
# Epoch 100/100
# 138/138 [==============================] - 51s 367ms/step - loss: 0.1459 - accuracy: 0.9414 - val_loss: 0.2104 - val_accuracy: 0.9236 - lr: 1.0000e-04

# %%
DenseNet121_time
# Out:
# 6696.470325708389

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history_DenseNet121.history['loss']);
plt.plot(history_DenseNet121.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(history_DenseNet121.history['accuracy']);
plt.plot(history_DenseNet121.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %%
loss_DenseNet121,acc_DenseNet121 = model_DenseNet121.evaluate(test_generator)
print("%s: %.4f" % ("Evaluate Test Loss", loss_DenseNet121))
print("%s: %.4f" % ("Evaluate Test accuracy", acc_DenseNet121))
# Out:
# 50/50 [==============================] - 6s 123ms/step - loss: 0.1917 - accuracy: 0.9262
# Evaluate Test Loss: 0.1917
# Evaluate Test accuracy: 0.9262

# %%
image=plt.imread('../input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_A4MT_20020212/TCGA_FG_A4MT_20020212_1.tif')
image=cv2.resize(image,dsize=(256,256))
image=image /255.0
image_ex=np.expand_dims(image,axis=0)
image_mask=plt.imread('../input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_A4MT_20020212/TCGA_FG_A4MT_20020212_1_mask.tif')

classes={0:'Not Tumor', 1:'Tumor'}
# Make prediction
prediction = model_DenseNet121.predict(image_ex)

decoded_predictions = [classes[i] for i in np.argmax(prediction, axis=1)]
titDudoan = decoded_predictions[0]
xacsuat = max(prediction[0])*100
# In kết quả
print('Predictions:', prediction)
print('Độ chính xác: ({:.3f} %)'.format(xacsuat))
print('Dự đoán: {}'.format(titDudoan))
print('DenseNet121 Prediction')

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Brain MRI");
plt.subplot(1,2,2)
plt.imshow(image_mask)
plt.title("Mask");
plt.show()
print("===========================================================================================================")

image=plt.imread('../input/lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_11.tif')
image=cv2.resize(image,dsize=(256,256))
image=image /255.0
image_ex=np.expand_dims(image,axis=0)
image_mask=plt.imread('../input/lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_11_mask.tif')

classes={0:'Not Tumor', 1:'Tumor'}
# Make prediction
prediction = model_DenseNet121.predict(image_ex)

decoded_predictions = [classes[i] for i in np.argmax(prediction, axis=1)]
titDudoan = decoded_predictions[0]
xacsuat = max(prediction[0])*100
# In kết quả
print('Predictions:', prediction)
print('Độ chính xác: ({:.3f} %)'.format(xacsuat))
print('Dự đoán: {}'.format(titDudoan))
print('DenseNet121 Prediction')

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Brain MRI");
plt.subplot(1,2,2)
plt.imshow(image_mask)
plt.title("Mask");
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predictions: [[9.9993098e-01 6.8988884e-05]]
# Độ chính xác: (99.993 %)
# Dự đoán: Not Tumor
# DenseNet121 Prediction
# ===========================================================================================================
# 1/1 [==============================] - 0s 32ms/step
# Predictions: [[8.0550695e-04 9.9919444e-01]]
# Độ chính xác: (99.919 %)
# Dự đoán: Tumor
# DenseNet121 Prediction

# %%
prediction = model_DenseNet121.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
# Out:
# 50/50 [==============================] - 4s 51ms/step
# 0.926208651399491
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       506
#            1       0.89      0.90      0.90       280
#
#     accuracy                           0.93       786
#    macro avg       0.92      0.92      0.92       786
# weighted avg       0.93      0.93      0.93       786
